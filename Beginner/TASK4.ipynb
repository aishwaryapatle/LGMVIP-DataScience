# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryapatle/LGMVIP-DataScience/blob/main/Beginner/TASK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > # **LGM VIRTUAL INTERNSHIP PROGRAM 2021**

# %% [markdown]
# **Beginner Level TASK 04 - Image to Pencil Sketch in Python**

# %% [markdown]
# **Domain: DATA SCIENCE**

# %% [markdown]
# **AUTHOR - Aishwarya PATLE**

# %% [markdown]
# > **Importing Libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# > **Reading the Original Image**

# %%
image = cv2.imread("fighters.png")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1300x775 at 0x7F41CD889C10>

# %% [markdown]
# > **Convert the RBG image to grayscale**

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=1300x775 at 0x7F41CD8E1250>

# %% [markdown]
# > **Invert the grayscale image**

# %%
invert_img = cv2.bitwise_not(gray_img)
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=1300x775 at 0x7F41CD8C8AD0>

# %% [markdown]
# > **Apply a Guassian Blur**

# %%
smoothing_img = cv2.GaussianBlur(invert_img, (21,21), sigmaX=0, sigmaY=0)
cv2_imshow(smoothing_img)
# Out:
# <PIL.Image.Image image mode=L size=1300x775 at 0x7F41CD8C87D0>

# %% [markdown]
# > **Blend the grayscale image with blurred negative**

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255-y, scale=256)

# %%
final_img = dodgeV2(gray_img, smoothing_img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=1300x775 at 0x7F41CD87D250>

# %% [markdown]
# > **THANK YOU!!**
